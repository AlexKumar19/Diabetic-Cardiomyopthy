# %%
import random
numlist = []
for i in range(900):
    number=random.randrange(0,170000000)
    numlist.append(number)
print(numlist)
# Out:
# [33405983, 84065673, 92538165, 29303606, 61616461, 56882583, 127107389, 24221029, 122200260, 138354730, 23611968, 145812816, 47796608, 144791716, 145576837, 155060116, 75954274, 2593612, 151569743, 72525865, 152597941, 98336265, 70644335, 161950455, 134497216, 43945552, 105462408, 139441619, 129718581, 84435298, 82661868, 40575937, 24771591, 24411306, 27316721, 21634271, 71720173, 81049798, 1406420, 75898588, 140153564, 147328174, 115559461, 83200304, 98077975, 57634725, 71840122, 149536592, 118771429, 35916851, 108352076, 22823917, 80762180, 23848979, 87459473, 129959080, 90368242, 81700181, 35202146, 49979230, 75698708, 159120938, 81462629, 126919815, 62956096, 18968610, 154367280, 127759894, 136196869, 47628306, 118014837, 30438535, 144605462, 26957911, 16545093, 63957005, 160299905, 63235329, 44202823, 48941216, 105586592, 66848210, 43900337, 18093341, 97931436, 105353385, 81140900, 152472145, 112179220, 115291260, 27314405, 19107778, 97791402, 77236479, 125461179, 41968928, 1159
# ...

# %%
import random
new = []
for i in range(30):
    new.append(random.randrange(0,170000000))
print(new)
# Out:
# [70002669, 142192748, 127108845, 124813935, 79806623, 32234510, 131115197, 147522343, 118349013, 166354006, 43810033, 59794454, 12155544, 36687792, 72795527, 88574958, 168512051, 78079965, 169151263, 44445401, 124257417, 13263149, 52829192, 13317055, 5642856, 103943298, 131708119, 90729062, 154051778, 88443555]
